# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
file = "Data/temp_full.csv"

# %%
df = pd.read_csv(file, encoding = 'latin-1')
df.head()
# Out:
#    ï»¿Area Code         Area  Months Code   Months  Element Code  \
# 0             2  Afghanistan         7001  January          7271
# 1             2  Afghanistan         7001  January          7271
# 2             2  Afghanistan         7001  January          7271
# 3             2  Afghanistan         7001  January          7271
# 4             2  Afghanistan         7001  January          7271
#
#               Element  Year Code  Year Unit  Value Flag
# 0  Temperature change       1961  1961  Â°C  0.993   Fc
# 1  Temperature change       1962  1962  Â°C  0.137   Fc
# 2  Temperature change       1963  1963  Â°C  2.441   Fc
# 3  Temperature change       1964  1964  Â°C -5.359   Fc
# 4  Temperature change       1965  1965  Â°C  2.211   Fc

# %%
for col in df.columns:
    print(col)
# Out:
# ï»¿Area Code
# Area
# Months Code
# Months
# Element Code
# Element
# Year Code
# Year
# Unit
# Value
# Flag

# %%
df_1 = pd.DataFrame(df)
df_1
# Out:
#         ï»¿Area Code                   Area  Months Code    Months  \
# 0                  2            Afghanistan         7001   January
# 1                  2            Afghanistan         7001   January
# 2                  2            Afghanistan         7001   January
# 3                  2            Afghanistan         7001   January
# 4                  2            Afghanistan         7001   January
# ...              ...                    ...          ...       ...
# 161635          5849  Non-Annex I countries         7012  December
# 161636          5849  Non-Annex I countries         7012  December
# 161637          5849  Non-Annex I countries         7012  December
# 161638          5849  Non-Annex I countries         7012  December
# 161639          5849  Non-Annex I countries         7012  December
#
#         Element Code             Element  Year Code  Year Unit  Value Flag
# 0               7271  Temperature change       1961  1961  Â°C  0.993   Fc
# ...

# %%
clean_df = df_1.drop(["ï»¿Area Code", "Months Code", "Element Code" , "Element" , "Year Code", "Unit", "Flag"], axis =1)
clean_df
# Out:
#                          Area    Months  Year  Value
# 0                 Afghanistan   January  1961  0.993
# 1                 Afghanistan   January  1962  0.137
# 2                 Afghanistan   January  1963  2.441
# 3                 Afghanistan   January  1964 -5.359
# 4                 Afghanistan   January  1965  2.211
# ...                       ...       ...   ...    ...
# 161635  Non-Annex I countries  December  2014  0.688
# 161636  Non-Annex I countries  December  2015  0.986
# 161637  Non-Annex I countries  December  2016  1.518
# 161638  Non-Annex I countries  December  2017  0.966
# 161639  Non-Annex I countries  December  2018  0.855
#
# [161640 rows x 4 columns]

# %%
new_df = pd.DataFrame(clean_df)
new_df
# Out:
#                          Area    Months  Year  Value
# 0                 Afghanistan   January  1961  0.993
# 1                 Afghanistan   January  1962  0.137
# 2                 Afghanistan   January  1963  2.441
# 3                 Afghanistan   January  1964 -5.359
# 4                 Afghanistan   January  1965  2.211
# ...                       ...       ...   ...    ...
# 161635  Non-Annex I countries  December  2014  0.688
# 161636  Non-Annex I countries  December  2015  0.986
# 161637  Non-Annex I countries  December  2016  1.518
# 161638  Non-Annex I countries  December  2017  0.966
# 161639  Non-Annex I countries  December  2018  0.855
#
# [161640 rows x 4 columns]

# %%
col_new_df = new_df.rename(columns = {"Area" : "Country", "Months" : "Month" , "Value" : "Change in Temp (C)"})
col_new_df
# Out:
#                       Country     Month  Year  Change in Temp (C)
# 0                 Afghanistan   January  1961               0.993
# 1                 Afghanistan   January  1962               0.137
# 2                 Afghanistan   January  1963               2.441
# 3                 Afghanistan   January  1964              -5.359
# 4                 Afghanistan   January  1965               2.211
# ...                       ...       ...   ...                 ...
# 161635  Non-Annex I countries  December  2014               0.688
# 161636  Non-Annex I countries  December  2015               0.986
# 161637  Non-Annex I countries  December  2016               1.518
# 161638  Non-Annex I countries  December  2017               0.966
# 161639  Non-Annex I countries  December  2018               0.855
#
# [161640 rows x 4 columns]

# %%
#export data into csv
col_new_df.to_csv('Final_CSVs/temp_full.csv', index = False)
