# %%
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine

# %%
file = "Eutrophication_Food_Production.csv"
file_df = pd.read_csv(file)
file_df.head()
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1         Maize (Meal)              0.3          0.0   0.5         0.1
# 2        Barley (Beer)              0.0          0.0   0.2         0.1
# 3              Oatmeal              0.0          0.0   1.4         0.0
# 4                 Rice              0.0          0.0   3.6         0.1
#
#    Transport  Packging  Retail  Total_emissions  \
# 0        0.1       0.1     0.1              1.4
# 1        0.1       0.1     0.0              1.1
# 2        0.0       0.5     0.3              1.1
# 3        0.1       0.1     0.0              1.6
# 4        0.1       0.1     0.1              4.0
#
#    Eutrophying emissions per 1000kcal  ...  \
# 0                                 NaN  ...
# 1                                 NaN  ...
# 2                                 NaN  ...
# 3                            4.281357  ...
# ...

# %%
eutrophication_df = file_df[["Food product","Eutrophying emissions per 1000kcal","Eutrophying emissions per kilogram","Eutrophying emissions per 100g protein"]]
eutrophication_df.head()
# Out:
#           Food product  Eutrophying emissions per 1000kcal  \
# 0  Wheat & Rye (Bread)                                 NaN
# 1         Maize (Meal)                                 NaN
# 2        Barley (Beer)                                 NaN
# 3              Oatmeal                            4.281357
# 4                 Rice                            9.514379
#
#    Eutrophying emissions per kilogram  Eutrophying emissions per 100g protein
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                               11.23                                8.638462
# 4                               35.07                               49.394366

# %%
eutro_df=eutrophication_df.dropna()

# %%
eutro_df
# Out:
#          Food product  Eutrophying emissions per 1000kcal  \
# 3             Oatmeal                            4.281357
# 4                Rice                            9.514379
# 5            Potatoes                            4.754098
# 6             Cassava                            0.708419
# 9        Other Pulses                            5.008798
# 10               Peas                            2.173410
# 11               Nuts                            3.113821
# 12         Groundnuts                            2.437931
# 20           Tomatoes                           39.526316
# 21     Onions & Leeks                            8.756757
# 22    Root Vegetables                            4.351351
# 23          Brassicas                           29.470588
# 25       Citrus Fruit                            7.000000
# 26            Bananas                            5.483333
# 27             Apples                            3.020833
# ...

# %%
file2 = "wri_eutrophic_hypoxic_dataset.csv"
file2_df = pd.read_csv(file2)
file2_df.head()
# Out:
#    ID                          System                      Country        Lat  \
# 0   1                   McMurdo Sound                   Antarctica -77.850000
# 1   2  Sand-mining dock-South Barbuda            Antigua & Barbuda  17.116670
# 2   4                  Beaufort Inlet  Australia-Western Australia -34.459000
# 3   5                  Bellambi Gully    Australia-New South Wales -34.407017
# 4   7              Cabbage Tree Basin    Australia-New South Wales -34.088639
#
#          Long  Decade  Hypoxia Current  \
# 0  166.651000     1990        Improved
# 1  -61.700000     1990        Seasonal
# 2  118.888000     1930        Episodic
# 3  150.900178     1990             NaN
# 4  151.126756     1980        Seasonal
#
#                                             Benthic   \
# 0  Abundance reduced by 1/3, diversity high or hi...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
columns = ['Country']

for col in columns:
    file2_df[col] = file2_df[col].str.split('-', expand=True)

# %%
#file2_df['new col'] = list

# %%
file2_df
# Out:
#       ID                              System            Country        Lat  \
# 0      1                       McMurdo Sound         Antarctica -77.850000
# 1      2      Sand-mining dock-South Barbuda  Antigua & Barbuda  17.116670
# 2      4                      Beaufort Inlet          Australia -34.459000
# 3      5                      Bellambi Gully          Australia -34.407017
# 4      7                  Cabbage Tree Basin          Australia -34.088639
# ..   ...                                 ...                ...        ...
# 771  890         Western Florida Bay (FKNMS)                 US  24.799022
# 772  891      Lower Keys (Gulf-side) (FKNMS)                 US  24.715936
# 773  892  Lower Keys (Atlantic-side) (FKNMS)                 US  24.549794
# 774  893                 Middle Keys (FKNMS)                 US  24.946192
# 775  894                  Upper Keys (FKNMS)                 US  25.294911
#
#            Long  Decade  Hypoxia Current  \
# ...

# %%
eutro_hypoxic_df=file2_df[["ID", "Country", "Lat", "Long", "Classification"]]
eutro_hypoxic_df.head()
# Out:
#    ID            Country        Lat        Long Classification
# 0   1         Antarctica -77.850000  166.651000       Improved
# 1   2  Antigua & Barbuda  17.116670  -61.700000      Eutrophic
# 2   4          Australia -34.459000  118.888000        Hypoxic
# 3   5          Australia -34.407017  150.900178      Eutrophic
# 4   7          Australia -34.088639  151.126756        Hypoxic

# %%
eutro_df.to_csv('Final_CSVs/Food_Production_Eutrophication.csv', index = False)

# %%
eutro_hypoxic_df.to_csv('Final_CSVs/Eutrophication_Hypoxia_Coordinates.csv', index = False)

# %%
#conn_str = "{}://{}:{}@{}:{}/{}".format(
 #                                  "postgresql+psycopg2", 
 #                                 db_server_info["user"], 
 #                                 db_server_info["password"], 
 #                                 db_server_info["host"], 
 #                                 db_server_info["port"], 
 #                                 db_server_info["dbname"]) 
#alchemyEngine = create_engine(conn_str, pool_recycle=3600)
#postgreSQLConnection = alchemyEngine.connect()

# %%
#eutro_hypoxic_df.to_sql("GHG", postgreSQLConnection, index=False, if_exists='append')
