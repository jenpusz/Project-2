# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Final_CSVs/temp_full.csv"
temp_full_df = pd.read_csv(csv_file)
temp_full_df.head()
# Out:
#        Country    Month  Year  Change in Temp (C)
# 0  Afghanistan  January  1961               0.993
# 1  Afghanistan  January  1962               0.137
# 2  Afghanistan  January  1963               2.441
# 3  Afghanistan  January  1964              -5.359
# 4  Afghanistan  January  1965               2.211

# %%
csv_file = "Final_CSVs/temp_simple.csv"
temp_simple_df = pd.read_csv(csv_file)
temp_simple_df.head()
# Out:
#        Country    Month  Year  Change in Temp (C)
# 0  Afghanistan  January  1961               0.993
# 1  Afghanistan  January  1962               0.137
# 2  Afghanistan  January  1963               2.441
# 3  Afghanistan  January  1964              -5.359
# 4  Afghanistan  January  1965               2.211

# %%
csv_file = "Final_CSVs/year_temp.csv"
year_temp_df = pd.read_csv(csv_file)
year_temp_df.head()
# Out:
#        Country  Year  Change in Temp (C)
# 0  Afghanistan  1961              -0.059
# 1  Afghanistan  1962              -0.154
# 2  Afghanistan  1963               0.820
# 3  Afghanistan  1964              -0.728
# 4  Afghanistan  1965               0.001

# %%
csv_file = "Final_CSVs/ghg_contributor.csv"
ghg_df = pd.read_csv(csv_file)
ghg_df.head()
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1         Maize (Meal)              0.3          0.0   0.5         0.1
# 2        Barley (Beer)              0.0          0.0   0.2         0.1
# 3              Oatmeal              0.0          0.0   1.4         0.0
# 4                 Rice              0.0          0.0   3.6         0.1
#
#    Transport  Packging  Retail  Total_emissions  \
# 0        0.1       0.1     0.1              1.4
# 1        0.1       0.1     0.0              1.1
# 2        0.0       0.5     0.3              1.1
# 3        0.1       0.1     0.0              1.6
# 4        0.1       0.1     0.1              4.0
#
#    Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  ...  \
# 0                                                NaN         ...
# 1                                                NaN         ...
# 2                                                NaN         ...
# 3                                           4.281357         ...
# 4                                           9.514379         ...
#
#    Freshwater withdrawals per 100g protein (liters per 100g protein)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         371.076923
# 4                                        3166.760563
#
#    Freshwater withdrawals per kilogram (liters per kilogram)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              482.4
# 4                                             2248.4
#
#    Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           0.945482
# 4                                           1.207271
#
#    Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           1.907692
# 4                                           6.267606
#
#    Land use per 1000kcal (m² per 1000kcal)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                 2.897446
# 4                                 0.759631
#
#    Land use per kilogram (m² per kilogram)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      7.6
# 4                                      2.8
#
#    Land use per 100g protein (m² per 100g protein)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                         5.846154
# 4                                         3.943662
#
#    Scarcity-weighted water use per kilogram (liters per kilogram)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            18786.2
# 4                                            49576.3
#
#    Scarcity-weighted water use per 100g protein (liters per 100g protein)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                        14450.92308
# 4                                        69825.77465
#
#    Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                        7162.104461
# 4                                       13449.891480
#
# [5 rows x 23 columns]

# %%
csv_file = "Final_CSVs/world_agriculture_emissions.csv"
world_ag_df = pd.read_csv(csv_file)
world_ag_df.head()
# Out:
#          Area               Item          Element  Year       Unit       Value
# 436017  World  Agriculture total  Emissions (CH4)  1961  gigagrams  90652.0610
# 436018  World  Agriculture total  Emissions (CH4)  1962  gigagrams  92404.3037
# 436019  World  Agriculture total  Emissions (CH4)  1963  gigagrams  93188.6930
# 436020  World  Agriculture total  Emissions (CH4)  1964  gigagrams  94846.6162
# 436021  World  Agriculture total  Emissions (CH4)  1965  gigagrams  96170.8303

# %%
csv_file = "Final_CSVs/Eutrophication_Hypoxia_Coordinates.csv"
eut_coord_df = pd.read_csv(csv_file)
eut_coord_df.head()
# Out:
#    ID            Country        Lat        Long Classification
# 0   1         Antarctica -77.850000  166.651000       Improved
# 1   2  Antigua & Barbuda  17.116670  -61.700000      Eutrophic
# 2   4          Australia -34.459000  118.888000        Hypoxic
# 3   5          Australia -34.407017  150.900178      Eutrophic
# 4   7          Australia -34.088639  151.126756        Hypoxic

# %%
csv_file = "Final_CSVs/Food_Production_Eutrophication.csv"
food_eut_df = pd.read_csv(csv_file)
food_eut_df.head()
# Out:
#    Food product  Eutrophying emissions per 1000kcal  \
# 0       Oatmeal                            4.281357
# 1          Rice                            9.514379
# 2      Potatoes                            4.754098
# 3       Cassava                            0.708419
# 4  Other Pulses                            5.008798
#
#    Eutrophying emissions per kilogram  Eutrophying emissions per 100g protein
# 0                               11.23                                8.638462
# 1                               35.07                               49.394366
# 2                                3.48                               20.470588
# 3                                0.69                                7.666667
# 4                               17.08                                7.977581

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Climate_Temp')
conn = engine.connect()

# %%
temp_full_df.to_sql(name= 'temp_full', con=engine, if_exists='append', index=False)
temp_simple_df.to_sql(name='temp_simple', con=engine, if_exists='append', index=False)
year_temp_df.to_sql(name='year_temp', con=engine, if_exists='append', index=False)
ghg_df.to_sql(name='ghg', con=engine, if_exists='append', index=False)
world_ag_df.to_sql(name='world_agriculture_emissions', con=engine, if_exists='append', index=False)
eut_coord_df.to_sql(name='regions', con=engine, if_exists='append', index=False)
food_eut_df.to_sql(name='food_production', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# InvalidTextRepresentation: invalid input syntax for type integer: "Agriculture total"
# LINE 1: ...ement", "Year", "Unit", "Value") VALUES ('World', 'Agricultu...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-12-c9ddc19f6c72> in <module>
#       3 year_temp_df.to_sql(name='year_temp', con=engine, if_exists='append', index=False)
#       4 ghg_df.to_sql(name='ghg', con=engine, if_exists='append', index=False)
# ----> 5 world_ag_df.to_sql(name='world_agriculture_emissions', con=engine, if_exists='append', index=False)
#       6 eut_coord_df.to_sql(name='regions', con=engine, if_exists='append', index=False)
#       7 food_eut_df.to_sql(name='food_production', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                             break
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     901                 kwargs = {}
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#     905                 statement,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# DataError: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type integer: "Agriculture total"
# LINE 1: ...ement", "Year", "Unit", "Value") VALUES ('World', 'Agricultu...
#                                                              ^
#
# [SQL: INSERT INTO world_agriculture_emissions ("Area", "Item", "Element", "Year", "Unit", "Value") VALUES (%(Area)s, %(Item)s, %(Element)s, %(Year)s, %(Unit)s, %(Value)s)]
# [parameters: ({'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1961, 'Unit': 'gigagrams', 'Value': 90652.061}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1962, 'Unit': 'gigagrams', 'Value': 92404.3037}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1963, 'Unit': 'gigagrams', 'Value': 93188.693}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1964, 'Unit': 'gigagrams', 'Value': 94846.6162}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1965, 'Unit': 'gigagrams', 'Value': 96170.8303}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1966, 'Unit': 'gigagrams', 'Value': 98014.3746}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1967, 'Unit': 'gigagrams', 'Value': 99818.7778}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (CH4)', 'Year': 1968, 'Unit': 'gigagrams', 'Value': 101281.5473}  ... displaying 10 of 228 total bound parameter sets ...  {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (N2O)', 'Year': 2016, 'Unit': 'gigagrams', 'Value': 7670.5374}, {'Area': 'World', 'Item': 'Agriculture total', 'Element': 'Emissions (N2O)', 'Year': 2017, 'Unit': 'gigagrams', 'Value': 7826.7186})]
# (Background on this error at: http://sqlalche.me/e/14/9h9h)

# %%
pd.read_sql_query('select * from temp_full', con=engine).head()

# %%
pd.read_sql_query('select * from temp_simple', con=engine).head()

# %%
pd.read_sql_query('select * from year_temp ', con=engine).head()

# %%
pd.read_sql_query('select * from ghg ', con=engine).head()

# %%
pd.read_sql_query('select * from emission_from_agriculture ', con=engine).head()

# %%
pd.read_sql_query('select * from regions ', con=engine).head()

# %%
pd.read_sql_query('select * from food_production ', con=engine).head()
